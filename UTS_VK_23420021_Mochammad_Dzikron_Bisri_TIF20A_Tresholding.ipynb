# %% [markdown]
# <a href="https://colab.research.google.com/github/Dzikronb/UTS-VK_23420021_Mochammad-Dzikron-Bisri_TIF20A_Tresholding/blob/main/UTS_VK_23420021_Mochammad_Dzikron_Bisri_TIF20A_Tresholding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 
import numpy as np 
from google.colab.patches import cv2_imshow

# %%
image1 = cv2.imread('spanduk1.jpg')
cv2_imshow(image1)
# Out:
# <PIL.Image.Image image mode=RGB size=306x357 at 0x7F1C9D560520>

# %%
rambu_gray = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)
cv2_imshow(rambu_gray)
# Out:
# <PIL.Image.Image image mode=L size=306x357 at 0x7F1CCC0AA050>

# %%
ret, thresh1 = cv2.threshold(rambu_gray, 221, 50, cv2.THRESH_BINARY)
ret, thresh2 = cv2.threshold(rambu_gray, 221, 50, cv2.THRESH_BINARY_INV)
ret, thresh3 = cv2.threshold(rambu_gray, 221, 50, cv2.THRESH_TRUNC)
ret, thresh4 = cv2.threshold(rambu_gray, 221, 50, cv2.THRESH_TOZERO)
ret, thresh5 = cv2.threshold(rambu_gray, 221, 50, cv2.THRESH_TOZERO_INV)

# %%
cv2_imshow(thresh1)
cv2_imshow(thresh2)
cv2_imshow(thresh3)
cv2_imshow(thresh4)
cv2_imshow(thresh5)
# Out:
# <PIL.Image.Image image mode=L size=306x357 at 0x7F1C9D456A40>
# <PIL.Image.Image image mode=L size=306x357 at 0x7F1C9D457640>
# <PIL.Image.Image image mode=L size=306x357 at 0x7F1CCC0A9B70>
# <PIL.Image.Image image mode=L size=306x357 at 0x7F1C9D456D10>
# <PIL.Image.Image image mode=L size=306x357 at 0x7F1CCC0A9B70>
